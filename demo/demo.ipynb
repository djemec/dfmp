# %%
from pictogram_people import pictogram
import matplotlib.pyplot as plt

# %%
ax = pictogram(
    ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I'],
    [41, 39, 51, 78, 50, 40, 29, 45, 13],
)
plt.title('a Title')
plt.show('Basic example 1')

# %%
ax = pictogram(
    ['J', 'K', 'L', 'M', 'N', 'O', 'P', 'Q', 'R'],
    [12.1, 21, 13.3, 44.2, 18.4, 26.5, 30.2, 32.2, 10.2],
)
plt.xlabel('categories')
plt.show()

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
ax = pictogram(
    ['A', 'B', 'C'],
    [10, 50, 100],
    color=['gray', 'blue', 'green'],
)
plt.title('with colors')
plt.show()
